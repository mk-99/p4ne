# %%
import pandas as pd

# %%
d1 = pd.DataFrame([[10, 3, 18, 1], [7, 14, 15, 3]])

# %%
d1
# Out:
#     0   1   2  3
# 0  10   3  18  1
# 1   7  14  15  3

# %%
d2 = [d1]
d2
# Out:
# [    0   1   2  3
#  0  10   3  18  1
#  1   7  14  15  3,     0   1   2  3
#  0  10   3  18  1
#  1   7  14  15  3,     0   1   2  3
#  0  10   3  18  1
#  1   7  14  15  3]
