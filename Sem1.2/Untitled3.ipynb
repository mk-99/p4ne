# %%
import pandas as pd

# %%
df = pd.read_excel('/Users/mk/PycharmProjects/p4ne/Lab1.2/data_analysis_lab.xlsx')
df1 = pd.DataFrame([1, 2, 3], [4, 5, 6])

# %%
df
# Out:
#      Годы  Температура  Относит. температура  Активность  Unnamed: 4  \
# 0    1900      13.8321             53.794326         9.5         NaN
# 1    1901      13.7583             43.391578         2.7         NaN
# 2    1902      13.6537             28.647305         5.0         NaN
# 3    1903      13.5631             15.876452        24.4         NaN
# 4    1904      13.4806              4.247364        42.0         NaN
# ..    ...          ...                   ...         ...         ...
# 111  2011      14.4788            144.952277        55.7         NaN
# 112  2012      14.5240            151.323608        57.7         NaN
# 113  2013      14.5679            157.511692        64.9         NaN
# 114  2014      14.6408            167.787577        79.0         NaN
# 115  2015      14.7998            190.200000        52.6         NaN
#
#      Unnamed: 5 Unnamed: 6                                         Unnamed: 7
# ...

# %%
df.plot(x='Годы', y=['Активность', 'Относит. температура'])
df1.plot()

# %%
df.plot(x='Годы', y='Относит. температура')
